# %% [markdown]
# <a href="https://colab.research.google.com/github/mohannanwani/WorldHappinessReport/blob/main/WorldHappinessReport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-23701abe-01e9-4943-8d3c-9ed7652db916" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23701abe-01e9-4943-8d3c-9ed7652db916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
from dataandresources import DataAndResources
from happinessreportdata import HappinessData
from happinessreportdata import HappinessDataVisualization
from happinessmachinelearningmodel import HappinessML

# %%
happinessdata = pd.read_csv("/content/WorldHappinessReport.csv")

# %%
dataAndRes = DataAndResources(happinessdata)
happinessData = HappinessData(happinessdata)
happinessDataVis = HappinessDataVisualization()
happinessDataML = HappinessML(happinessdata)

# %%
happinessReport = dataAndRes.getHappinessData()

# %%
dataAndRes.getHappinessData()
# Out:
#     Country or region  ...  Year
# 0             Finland  ...  2019
# 1             Denmark  ...  2019
# 2              Norway  ...  2019
# 3             Iceland  ...  2019
# 4         Netherlands  ...  2019
# ..                ...  ...   ...
# 777            Rwanda  ...  2015
# 778             Benin  ...  2015
# 779             Syria  ...  2015
# 780           Burundi  ...  2015
# 781              Togo  ...  2015
#
# [782 rows x 11 columns]

# %%
dataAndRes.getHeadData(happinessReport)
# Out:
#   Country or region          Region  ...  Perceptions of corruption  Year
# 0           Finland  Western Europe  ...                      0.393  2019
# 1           Denmark  Western Europe  ...                      0.410  2019
# 2            Norway  Western Europe  ...                      0.341  2019
# 3           Iceland  Western Europe  ...                      0.118  2019
# 4       Netherlands  Western Europe  ...                      0.298  2019
#
# [5 rows x 11 columns]

# %%
dataAndRes.getTailData(happinessReport)
# Out:
#     Country or region  ...  Year
# 777            Rwanda  ...  2015
# 778             Benin  ...  2015
# 779             Syria  ...  2015
# 780           Burundi  ...  2015
# 781              Togo  ...  2015
#
# [5 rows x 11 columns]

# %%
happinessData.getColumnsOfHappinessData(happinessReport)
# Out:
# Index(['Country or region', 'Region', 'Overall rank', 'Score',
#        'GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
happinessData.getDataTypesOfHappinessData(happinessReport)
# Out:
# Country or region                object
# Region                           object
# Overall rank                      int64
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Year                              int64
# dtype: object

# %%
happinessReport = happinessData.renameColumns(happinessReport)

# %%
dataAndRes.getHeadData(happinessReport)
# Out:
#        Country          Region  Happiness_Rank  ...  Generosity  Corruption  Year
# 0      Finland  Western Europe               1  ...       0.153       0.393  2019
# 1      Denmark  Western Europe               2  ...       0.252       0.410  2019
# 2       Norway  Western Europe               3  ...       0.271       0.341  2019
# 3      Iceland  Western Europe               4  ...       0.354       0.118  2019
# 4  Netherlands  Western Europe               5  ...       0.322       0.298  2019
#
# [5 rows x 11 columns]

# %%
dataAndRes.getTailData(happinessReport)
# Out:
#      Country                           Region  ...  Corruption  Year
# 777   Rwanda               Sub-Saharan Africa  ...     0.55191  2015
# 778    Benin               Sub-Saharan Africa  ...     0.08010  2015
# 779    Syria  Middle East and Northern Africa  ...     0.18906  2015
# 780  Burundi               Sub-Saharan Africa  ...     0.10062  2015
# 781     Togo               Sub-Saharan Africa  ...     0.10731  2015
#
# [5 rows x 11 columns]

# %%
happinessData.areNullValuesPresent(happinessReport)
# Out:
#      Country  Region  Happiness_Rank  ...  Generosity  Corruption   Year
# 0      False   False           False  ...       False       False  False
# 1      False   False           False  ...       False       False  False
# 2      False   False           False  ...       False       False  False
# 3      False   False           False  ...       False       False  False
# 4      False   False           False  ...       False       False  False
# ..       ...     ...             ...  ...         ...         ...    ...
# 777    False   False           False  ...       False       False  False
# 778    False   False           False  ...       False       False  False
# 779    False   False           False  ...       False       False  False
# 780    False   False           False  ...       False       False  False
# 781    False   False           False  ...       False       False  False
#
# [782 rows x 11 columns]

# %%
happinessData.fillMissingValues(happinessReport)
# Out:
#          Country                           Region  ...  Corruption  Year
# 0        Finland                   Western Europe  ...     0.39300  2019
# 1        Denmark                   Western Europe  ...     0.41000  2019
# 2         Norway                   Western Europe  ...     0.34100  2019
# 3        Iceland                   Western Europe  ...     0.11800  2019
# 4    Netherlands                   Western Europe  ...     0.29800  2019
# ..           ...                              ...  ...         ...   ...
# 777       Rwanda               Sub-Saharan Africa  ...     0.55191  2015
# 778        Benin               Sub-Saharan Africa  ...     0.08010  2015
# 779        Syria  Middle East and Northern Africa  ...     0.18906  2015
# 780      Burundi               Sub-Saharan Africa  ...     0.10062  2015
# 781         Togo               Sub-Saharan Africa  ...     0.10731  2015
#
# [782 rows x 11 columns]

# %%
happinessData.dropDuplicatesIfAny(happinessReport)
# Out:
#          Country                           Region  ...  Corruption  Year
# 0        Finland                   Western Europe  ...     0.39300  2019
# 1        Denmark                   Western Europe  ...     0.41000  2019
# 2         Norway                   Western Europe  ...     0.34100  2019
# 3        Iceland                   Western Europe  ...     0.11800  2019
# 4    Netherlands                   Western Europe  ...     0.29800  2019
# ..           ...                              ...  ...         ...   ...
# 777       Rwanda               Sub-Saharan Africa  ...     0.55191  2015
# 778        Benin               Sub-Saharan Africa  ...     0.08010  2015
# 779        Syria  Middle East and Northern Africa  ...     0.18906  2015
# 780      Burundi               Sub-Saharan Africa  ...     0.10062  2015
# 781         Togo               Sub-Saharan Africa  ...     0.10731  2015
#
# [782 rows x 11 columns]

# %%
happinessDataVis.getHappinessScoreHist(happinessReport)

# %%
happinessDataVis.getGDPRange(happinessReport)

# %%
happinessDataVis.getPlotfeatureByfeature(happinessReport)

# %%
happinessReportCorr = happinessDataVis.getHappinessReportCorr(happinessReport)

# %%
happinessDataVis.getHeatMapofCorr(happinessReportCorr)

# %%
happinessScore_pt = happinessDataVis.getHappinessScorePivot(happinessReport)

# %%
happinessDataVis.getHappinessScoreOverYears(happinessScore_pt)

# %%
finlandHappinessScore_allyears = happinessDataVis.getFinlandHappinessOverYears(happinessReport)

# %%
happinessDataVis.getFinlandHappinessMap(finlandHappinessScore_allyears)

# %% [markdown]
# Top 10 Countries with high happiness score in year 2019

# %%
happinessReport2019_top10 = happinessDataVis.getTopTenHappyCountry2019(happinessReport)

# %%
happinessReport2019_top10
# Out:
#        Country                     Region  ...  Corruption  Year
# 9      Austria             Western Europe  ...       0.226  2019
# 8       Canada              North America  ...       0.308  2019
# 7  New Zealand  Australia and New Zealand  ...       0.380  2019
# 6       Sweden             Western Europe  ...       0.373  2019
# 5  Switzerland             Western Europe  ...       0.343  2019
# 4  Netherlands             Western Europe  ...       0.298  2019
# 3      Iceland             Western Europe  ...       0.118  2019
# 2       Norway             Western Europe  ...       0.341  2019
# 1      Denmark             Western Europe  ...       0.410  2019
# 0      Finland             Western Europe  ...       0.393  2019
#
# [10 rows x 11 columns]

# %%
happinessDataVis.topTenHappyCountryMap(happinessReport2019_top10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc8318c0-1569-491b-84fc-ddc401b01698" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc8318c0-1569-491b-84fc-ddc401b01698")) {
#                     Plotly.newPlot(
#                         'dc8318c0-1569-491b-84fc-ddc401b01698',
# ...

# %% [markdown]
# Least 10 Countries with low happiness score in year 2019

# %%
happinessReport2019_least10 = happinessDataVis.getLeastHappyCountry2019(happinessReport)

# %%
happinessReport2019_least10
# Out:
#                       Country  ...  Year
# 155               South Sudan  ...  2019
# 154  Central African Republic  ...  2019
# 153               Afghanistan  ...  2019
# 152                  Tanzania  ...  2019
# 151                    Rwanda  ...  2019
# 150                     Yemen  ...  2019
# 149                    Malawi  ...  2019
# 148                     Syria  ...  2019
# 147                  Botswana  ...  2019
# 146                     Haiti  ...  2019
#
# [10 rows x 11 columns]

# %%
happinessDataVis.leastTenHappyCountryMap(happinessReport2019_least10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c116e103-09cb-46de-90de-706275e4ff73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c116e103-09cb-46de-90de-706275e4ff73")) {
#                     Plotly.newPlot(
#                         'c116e103-09cb-46de-90de-706275e4ff73',
# ...

# %%
happinessReport
# Out:
#          Country                           Region  ...  Corruption  Year
# 0        Finland                   Western Europe  ...     0.39300  2019
# 1        Denmark                   Western Europe  ...     0.41000  2019
# 2         Norway                   Western Europe  ...     0.34100  2019
# 3        Iceland                   Western Europe  ...     0.11800  2019
# 4    Netherlands                   Western Europe  ...     0.29800  2019
# ..           ...                              ...  ...         ...   ...
# 777       Rwanda               Sub-Saharan Africa  ...     0.55191  2015
# 778        Benin               Sub-Saharan Africa  ...     0.08010  2015
# 779        Syria  Middle East and Northern Africa  ...     0.18906  2015
# 780      Burundi               Sub-Saharan Africa  ...     0.10062  2015
# 781         Togo               Sub-Saharan Africa  ...     0.10731  2015
#
# [782 rows x 11 columns]

# %%
report_2019 = happinessDataML.getReportsByYear(happinessReport,2019)

# %%
happinessDataML.happinessClassificationML(report_2019)

# %%
result = happinessDataML.happinessClassificationWithSVM(report_2019)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
actual = result[0]
prediction = result[1]

# %%
happinessDataML.printClassificationReport(actual,prediction)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.75      0.80         8
#          1.0       0.95      0.97      0.96        39
#
#     accuracy                           0.94        47
#    macro avg       0.90      0.86      0.88        47
# weighted avg       0.93      0.94      0.93        47

# %%
happinessDataML.happinessClassificationWithDotPlus(report_2019)

# %%
sentimentData = happinessDataVis.happinessSentimentAnalysis(report_2019)

# %%
sentimentData
# Out:
#                       Country              Region  ...          Remarks  Sentiment
# 0                     Finland      Western Europe  ...            Happy        1.0
# 1                     Denmark      Western Europe  ...            Happy        1.0
# 2                      Norway      Western Europe  ...            Happy        1.0
# 3                     Iceland      Western Europe  ...            Happy        1.0
# 4                 Netherlands      Western Europe  ...            Happy        1.0
# ..                        ...                 ...  ...              ...        ...
# 151                    Rwanda  Sub-Saharan Africa  ...       Less Happy        0.0
# 152                  Tanzania  Sub-Saharan Africa  ...       Less Happy        0.0
# 153               Afghanistan       Southern Asia  ...       Less Happy        0.0
# 154  Central African Republic  Sub-Saharan Africa  ...  Very less happy        0.0
# ...

# %%
happinessDataVis.plotHappinessSentimentAnalysis(sentimentData)
